# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from IPython.display import display

# %%
base_url = 'https://www.sciencedirect.com'
search_url = 'https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&' + \
      'sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset='

def scrape(url):
    
    response = requests.get(url)
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    all_data = []
    
    for index, result_item in enumerate(soup.select('.ResultItem.col-xs-24.push-m')):
        data = {}

        title_item = result_item.select_one('a.result-list-title-link')
        if title_item:
            data['title'] = title_item.text
            data['title_url'] = base_url + title_item.attrs['href']

        research_type_item = result_item.select_one('.article-type')
        if research_type_item:
            data['research_type'] = research_type_item.text

        journal_item = result_item.select_one('.SubType')
        if journal_item:
            data['journal'] = journal_item.text
            if data['journal'].endswith(', '): data['journal'] = data['journal'][:-2]

        author_item = result_item.select_one('.Authors')
        if author_item:
            data['author'] = author_item.text
            if data['author'].endswith(', '): data['author'] = data['author'][:-2]

        open_access_item = result_item.select_one('.open-access')
        data['open_access'] = open_access_item != None

        publication_link_item = result_item.select_one('.subtype-srctitle-link')
        if publication_link_item:
            data['publication_link'] = base_url + publication_link_item.attrs['href']

        all_data.append(data)
        
    return all_data

# %%
# Iterate sites and scrape
data = []
for n in range(15):
    url = search_url + str(n * 100)
    print('Processing ', url)
    data += scrape(url)
df = pd.DataFrame(data)
display(df.head())
df.shape
# Out:
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=0
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=100
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=200
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=300
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=400
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=500
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=600
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=700
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=800
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=900
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=1000
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=1100
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=1200
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=1300
# Processing  https://www.sciencedirect.com/search?qs=migraine%20AND%20acupuncture&show=100&sortBy=relevance&articleTypes=REV%2CFLA%2CABS%2CCRP%2CCNF&offset=1400
#                                               author  \
# 0            Jia Xu, Fu-qing Zhang, Jian Pei, Jun Ji
# 1                           Xianmin Yu, Alan Salmoni
# 2  Zhengjie Li, Fang Zeng, Tao Yin, Lei Lan, Jian...
# 3                                      Yılmaz Sezgin
# 4                          Jia-yuan NIU, Gang-qi FAN
#
#                                              journal  open_access  \
# 0  Journal of Integrative Medicine, In press, acc...        False
# 1  Journal of Acupuncture and Meridian Studies, I...         True
# 2  NeuroImage: Clinical, Volume 15, 2017, Pages 3...         True
# 3  Journal of Acupuncture and Meridian Studies, V...         True
# 4  World Journal of Acupuncture - Moxibustion, Vo...        False
#
#                                     publication_link     research_type  \
# 0  https://www.sciencedirect.com/science/journal/...    Review article
# 1  https://www.sciencedirect.com/science/journal/...  Research article
# 2  https://www.sciencedirect.com/science/journal/...  Research article
# 3  https://www.sciencedirect.com/science/journal/...       Case report
# 4  https://www.sciencedirect.com/science/journal/...  Research article
#
#                                                title  \
# 0  Acupuncture for migraine without aura: a syste...
# 1  Comparison of the Prophylactic Effect Between ...
# 2  Acupuncture modulates the abnormal brainstem a...
# 3  The Acupuncture Therapeutic Approach in Tempor...
# 4  Specific effect of acupuncture on the neural p...
#
#                                            title_url
# 0  https://www.sciencedirect.com/science/article/...
# 1  https://www.sciencedirect.com/science/article/...
# 2  https://www.sciencedirect.com/science/article/...
# 3  https://www.sciencedirect.com/science/article/...
# 4  https://www.sciencedirect.com/science/article/...
# (1463, 7)

# %%
# Reorder columns
columns = ['author', 'title', 'title_url', 'journal', 'publication_link', 'open_access']
df = df[columns]

# %%
# Export to excel
df.to_excel('sciencedirect_result.xlsx', index=False)
